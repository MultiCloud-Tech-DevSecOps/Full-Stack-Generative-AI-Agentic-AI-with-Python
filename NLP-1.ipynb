# %%
import os
import nltk
nltk.download('punkt')
# Out:
# [nltk_data] Downloading package punkt to
# [nltk_data]     C:\Users\DevSecOps\AppData\Roaming\nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# True

# %%
import nltk
nltk.data.path.append('/c/Users/DevSecOps/AppData/Roaming/nltk_data')
nltk.download('punkt', download_dir='/c/Users/DevSecOps/AppData/Roaming/nltk_data')
# Out:
# [nltk_data] Downloading package punkt to
# [nltk_data]     /c/Users/DevSecOps/AppData/Roaming/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# True

# %%
import nltk.corpus

# %%
AI = '''Artificial Intelligence refers to the intelligence of machines. This is in 
humans and animals. With Artificial Intelligence, machines perform functions such 
a problem-solving. Most noteworthy, Artificial Intelligence is the simulation of 
human It is probably the fastest-growing development in the World of technology 
and innov AI could solve major challenges and crisis situations.'''

# %%
AI
# Out:
# 'Artificial Intelligence refers to the intelligence of machines. This is in \nhumans and animals. With Artificial Intelligence, machines perform functions such \na problem-solving. Most noteworthy, Artificial Intelligence is the simulation of \nhuman It is probably the fastest-growing development in the World of technology \nand innov AI could solve major challenges and crisis situations.'

# %%
type(AI)
# Out:
# str

# %%
from nltk.tokenize import word_tokenize

# %%
AI_token = word_tokenize (AI)
AI_token
# Out:
# ['Artificial',
#  'Intelligence',
#  'refers',
#  'to',
#  'the',
#  'intelligence',
#  'of',
#  'machines',
#  '.',
#  'This',
#  'is',
#  'in',
#  'humans',
#  'and',
#  'animals',
#  '.',
#  'With',
#  'Artificial',
#  'Intelligence',
#  ',',
#  'machines',
#  'perform',
#  'functions',
#  'such',
#  'a',
#  'problem-solving',
#  '.',
#  'Most',
#  'noteworthy',
#  ',',
#  'Artificial',
#  'Intelligence',
#  'is',
#  'the',
#  'simulation',
#  'of',
#  'human',
#  'It',
#  'is',
#  'probably',
#  'the',
#  'fastest-growing',
#  'development',
#  'in',
#  'the',
#  'World',
#  'of',
#  'technology',
#  'and',
#  'innov',
#  'AI',
#  'could',
#  'solve',
#  'major',
#  'challenges',
#  'and',
#  'crisis',
#  'situations',
#  '.']

# %%
len(AI_token)
# Out:
# 59

# %%
from nltk.tokenize import sent_tokenize

# %%
AI_Sent = sent_tokenize (AI) 
AI_Sent
# Out:
# ['Artificial Intelligence refers to the intelligence of machines.',
#  'This is in \nhumans and animals.',
#  'With Artificial Intelligence, machines perform functions such \na problem-solving.',
#  'Most noteworthy, Artificial Intelligence is the simulation of \nhuman It is probably the fastest-growing development in the World of technology \nand innov AI could solve major challenges and crisis situations.']

# %%
len (AI_Sent)
# Out:
# 4

# %%
from nltk.tokenize import blankline_tokenize   # displays the text in blank lines
AI_blank = blankline_tokenize (AI) 
AI_blank
# Out:
# ['Artificial Intelligence refers to the intelligence of machines. This is in \nhumans and animals. With Artificial Intelligence, machines perform functions such \na problem-solving. Most noteworthy, Artificial Intelligence is the simulation of \nhuman It is probably the fastest-growing development in the World of technology \nand innov AI could solve major challenges and crisis situations.']

# %%
len (AI_blank)
# Out:
# 1

# %%
from nltk.tokenize import WhitespaceTokenizer
wt = WhitespaceTokenizer().tokenize(AI)
wt
# Out:
# ['Artificial',
#  'Intelligence',
#  'refers',
#  'to',
#  'the',
#  'intelligence',
#  'of',
#  'machines.',
#  'This',
#  'is',
#  'in',
#  'humans',
#  'and',
#  'animals.',
#  'With',
#  'Artificial',
#  'Intelligence,',
#  'machines',
#  'perform',
#  'functions',
#  'such',
#  'a',
#  'problem-solving.',
#  'Most',
#  'noteworthy,',
#  'Artificial',
#  'Intelligence',
#  'is',
#  'the',
#  'simulation',
#  'of',
#  'human',
#  'It',
#  'is',
#  'probably',
#  'the',
#  'fastest-growing',
#  'development',
#  'in',
#  'the',
#  'World',
#  'of',
#  'technology',
#  'and',
#  'innov',
#  'AI',
#  'could',
#  'solve',
#  'major',
#  'challenges',
#  'and',
#  'crisis',
#  'situations.']

# %%
print(len(wt))
# Out:
# 53
